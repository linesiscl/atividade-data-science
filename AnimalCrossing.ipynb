# %%
import pandas as pd
import numpy as np

# %%
ac = pd.read_csv("villagers.csv")

# %%
ac.sample(5)
# Out:
#          Name   Species  Gender Personality    Hobby Birthday Catchphrase  \
# 215     Lucky       Dog    Male        Lazy     Play    4-Nov    rrr-owch
# 134  Felicity       Cat  Female       Peppy  Fashion   30-Mar      mimimi
# 338     Spork       Pig    Male        Lazy     Play    3-Sep       snork
# 127    Eloise  Elephant  Female      Snooty  Fashion    8-Dec     tooooot
# 47        Bob       Cat    Male        Lazy     Play    1-Jan     pthhpth
#
#     Favorite Song  Style 1 Style 2   Color 1   Color 2              Wallpaper  \
# 215    K.K. Dirge   Simple  Simple     Beige     White        ramshackle wall
# 134   K.K. Stroll     Cute    Cute    Yellow    Orange    backyard-fence wall
# 338   Forest Life   Simple  Active     Green  Colorful          woodland wall
# 127     K.K. Soul  Elegant  Simple     Green    Orange  yellow intricate wall
# 47     Neapolitan   Simple    Cute  Colorful       Red     blue playroom wall
#
#                      Flooring  \
# ...

# %%
ac.describe()
# Out:
#            Name Species Gender Personality   Hobby Birthday Catchphrase  \
# count       391     391    391         391     391      391         391
# unique      391      35      2           8       6      361         388
# top     Admiral     Cat   Male        Lazy  Nature   27-Jan     sweetie
# freq          1      23    204          60      66        2           2
#
#        Favorite Song Style 1 Style 2 Color 1 Color 2            Wallpaper  \
# count            391     391     391     391     391                  391
# unique            89       6       6      14      14                  154
# top      Forest Life  Simple  Simple   Black     Red  backyard-fence wall
# freq              15     118     110      47      53                   13
#
#              Flooring                                     Furniture List  \
# count             391                                                391
# unique            128                                                391
# ...

# %%
ac.sample(10)
# Out:
#          Name    Species  Gender Personality      Hobby Birthday Catchphrase  \
# 30       Beau       Deer    Male        Lazy     Nature    5-Apr    saltlick
# 331      Skye       Wolf  Female      Normal      Music   24-Mar     airmail
# 5       Alice      Koala  Female      Normal  Education   19-Aug      guvnor
# 218       Mac        Dog    Male        Jock    Fitness   11-Nov    woo woof
# 374  Victoria      Horse  Female       Peppy    Fitness   11-Jul  sugar cube
# 189      June        Cub  Female      Normal     Nature   21-May     rainbow
# 247       Nan       Goat  Female      Normal     Nature   24-Aug         kid
# 368    Twiggy       Bird  Female       Peppy    Fashion   13-Jul    cheepers
# 119     Drago  Alligator    Male        Lazy     Nature   12-Feb      burrrn
# 77      Cheri        Cub  Female       Peppy    Fashion   17-Mar     tralala
#
#       Favorite Song  Style 1   Style 2 Color 1     Color 2  \
# 30    Mountain Song   Simple      Cute   Beige      Orange
# ...

# %%
ac.query('Name.str.startswith("A")', engine="python")
# Out:
#         Name    Species  Gender Personality      Hobby Birthday Catchphrase  \
# 0    Admiral       Bird    Male      Cranky     Nature   27-Jan     aye aye
# 1    Agent S   Squirrel  Female       Peppy    Fitness    2-Jul    sidekick
# 2      Agnes        Pig  Female  Big Sister       Play   21-Apr     snuffle
# 3         Al    Gorilla    Male        Lazy    Fitness   18-Oct     ayyyeee
# 4    Alfonso  Alligator    Male        Lazy       Play    9-Jun    it'sa me
# 5      Alice      Koala  Female      Normal  Education   19-Aug      guvnor
# 6       Alli  Alligator  Female      Snooty    Fashion    8-Nov     graaagh
# 7     Amelia      Eagle  Female      Snooty      Music   19-Nov         cuz
# 8   Anabelle   Anteater  Female       Peppy    Fashion   16-Feb      snorty
# 9    Anchovy       Bird    Male        Lazy       Play    4-Mar      chuurp
# 10     Angus       Bull    Male      Cranky    Fitness   30-Apr      macmoo
# ...

# %%
ac.query('Name.str.startswith("Z")', engine= "python")
# Out:
#        Name  Species Gender Personality   Hobby Birthday Catchphrase  \
# 389    Zell     Deer   Male        Smug   Music    7-Jun       pronk
# 390  Zucker  Octopus   Male        Lazy  Nature    8-Mar       bloop
#
#        Favorite Song Style 1   Style 2 Color 1 Color 2         Wallpaper  \
# 389       K.K. Swing    Cool  Gorgeous  Purple    Gray    cityscape wall
# 390  Spring Blossoms  Simple      Cute    Blue  Yellow  chain-link fence
#
#                         Flooring  \
# 389  monochromatic tile flooring
# 390                backyard lawn
#
#                                         Furniture List Filename  \
# 389  1875;863;4129;4053;4053;3951;794;3775;4046;423...    der02
# 390  4042;4412;7526;4077;4077;3064;4077;3946;3617;3...    ocp02
#
#        Unique Entry ID
# 389  LodBWtdMRZbjFNga9
# 390  2F5tipHqgmWvWXTLC

# %% [markdown]
# #Considerações
# Os dados referem-se aos villagers (aldeões) do jogo Animal Crossing. Com o .describe() é possível obter algumas informações sobre eles, como por exemplo, o dado que mais aparece em cada categoria (top). Além disso, utilizamos .query() para descobrir quantas pessoas têm o nome começando com determinada letra. Seguem alguns exemplos:
# * Tem mais homens (Male) do que mulheres (Female)
# * Duas pessoas fazem aniversário no dia 27 de janeiro
# * Ninguém tem o mesmo nome, furniture list, filename e unique entry ID
# * Existem 35 espécies
# * Existem apenas 6 hobbies (Nature, Music, Fitness, Play, Fashion, Education)
# * 60 pessoas têm a personalidade lazy (preguiçoso)
# * Existem 8 personalidades (lazy, normal, jock, cranky, preppy, big sister, smug, snooty) e lazy é a que mais aparece
# * 23 villagers têm o nome começando com a letra A
# * Apenas 2 villagers têm o nome começando com a letra Z
# * 15 villagers têm a música Forest Life como sua favorita
# * As cores mais usadas são preto e vermelho
#
#
# Aline Fernandes - RM 97966
# Camilly Ishida - RM551474
